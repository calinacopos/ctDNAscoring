# %%
import pandas as pd
import numpy as np
import scipy as sp
import string
import random
import re
import collections
import matplotlib.pyplot as plt
from scipy.signal import welch, hanning

# %%
labels = pd.read_csv('Data/20190819_WPS_NORM.hackathon_sample_info_updated.csv')
labels = labels.fillna('N/A')
labels.rename(columns={'library':'PatientId', 'hotspot':'Oncogene'},inplace=True)

# %%
zeroPurity = labels[(labels['estimated.purity']==0) & (labels['ctdna.score']<=0.01)]

# %%
highPurity = labels[labels['estimated.purity']>=0.6]

# %%
print('Number of patient samples:',labels['PatientId'].unique().shape[0])
if (labels['PatientId'].unique().shape[0] != labels['PatientId'].shape[0]):
    print('Warning! Repeated patient IDs')
# Out:
# Number of patient samples: 1764

# %%
# Plasma/blood -- tissue concordance
n = 1000;
ind = np.random.randint(len(labels), size=n)
sample_ctdna = labels['ctdna.score'][ind]
sample_purity = labels['estimated.purity'][ind]
disc_ind = (sample_purity==0) | (sample_ctdna==0);
a = plt.scatter(sample_ctdna[~disc_ind],sample_purity[~disc_ind],s=60,marker='o',color='k',facecolors='none')
b = plt.scatter(sample_ctdna[disc_ind],sample_purity[disc_ind],s=60,marker='o',color='r',facecolors='none')
plt.title('Plasma/blood -- Tissue Concordance')
plt.ylabel('Tissue purity')
plt.xlabel('Plasma/blood circulating tumor DNA')
plt.legend([a,b],['Concordant samples','Disconcordant samples'])
plt.ylim((-0.05,1))
plt.xlim((-0.05,1))
plt.show()

# %%
# Perform pairs bootstrap for linear regression
def draw_bs_pairs_linreg(x, y, size=1):
    inds = np.arange(0,len(x))

    bs_slope_reps = np.empty(size)
    bs_intercept_reps = np.empty(size)

    for i in range(size):
        bs_inds = np.random.choice(inds, size=len(inds))
        bs_x, bs_y = x[bs_inds], y[bs_inds]
        bs_slope_reps[i], bs_intercept_reps[i] = np.polyfit(bs_x,bs_y,1)

    return bs_slope_reps, bs_intercept_reps

# %%
bs_slope_reps, bs_intercept_reps = draw_bs_pairs_linreg(labels['ctdna.score'].values,labels['estimated.purity'].values,1000)
x = np.array([0,1])

# Plot the bootstrap lines
for i in range(100):
    _ = plt.plot(x, 
                 bs_slope_reps[i]*x + bs_intercept_reps[i],
                 linewidth=0.5, alpha=0.2, color='red')
    
_ = plt.scatter(sample_ctdna,sample_purity,s=60,marker='o',color='k',facecolors='none')
plt.title('Plasma/blood -- Tissue Concordance')
plt.ylabel('Tissue purity')
plt.xlabel('Plasma/blood circulating tumor DNA')
plt.ylim((-0.05,1))
plt.xlim((-0.05,1))
plt.show()

# %%
# 95% confidence interval for the slope
print(np.percentile(bs_slope_reps, [2.5,97.5]))
# Out:
# [1.01588562 1.0428204 ]

# %%
data = pd.read_csv('Data/example_WPS_NORM.exons.collapsed.csv',sep='\t',header=None)
# 0: sample id (patient id)
# 1: chromosome
# 2: start of exon
# 3: end of exon e.g row 0 has 65 30 basepairs
# 4: (30 basepairs) - window protection score as defined in Snyder2016 paper normalized
# gene_id: roughly 600 genes per patient
# Data to be provided purity per sample: fraction of cancer cells detected in circulation (low purity: healthy cells)

# %%
data.head(10)
# Out:
#             0     1        2        3  \
# 0  LIB-ZIIEJE  chr1  3598930  3598995
# 1  LIB-ZIIEJE  chr1  3599624  3599745
# 2  LIB-ZIIEJE  chr1  3624113  3624356
# 3  LIB-ZIIEJE  chr1  3624140  3624356
# 4  LIB-ZIIEJE  chr1  3638585  3638772
# 5  LIB-ZIIEJE  chr1  3639918  3640034
# 6  LIB-ZIIEJE  chr1  3643679  3643789
# 7  LIB-ZIIEJE  chr1  3644192  3644335
# 8  LIB-ZIIEJE  chr1  3644693  3644782
# 9  LIB-ZIIEJE  chr1  3645891  3646013
#
#                                                    4  5  \
# 0  -0.735294,-0.735294,-0.735294,-0.735294,-0.735...  +
# 1  -0.780822,-0.780822,-0.780822,-0.780822,-0.726...  +
# 2  -0.988372,-0.977011,-0.988372,-0.977011,-1.011...  +
# 3  -1.360465,-1.364706,-1.364706,-1.376471,-1.348...  +
# 4  -1.100000,-1.083333,-1.024000,-1.015873,-0.968...  +
# 5  -0.550000,-0.524752,-0.490000,-0.470000,-0.550...  +
# 6  -0.823529,-0.768116,-0.753623,-0.753623,-0.775...  +
# 7  -0.974359,-1.000000,-1.000000,-0.974359,-0.975...  +
# 8  -1.628571,-1.540541,-1.540541,-1.447368,-1.447...  +
# 9  -0.978261,-1.065217,-1.000000,-1.021277,-0.938...  +
#
#                                                    6
# 0  gene_id "ENSG00000078900.10"; transcript_id "E...
# 1  gene_id "ENSG00000078900.10"; transcript_id "E...
# 2  gene_id "ENSG00000078900.10"; transcript_id "E...
# 3  gene_id "ENSG00000078900.10"; transcript_id "E...
# 4  gene_id "ENSG00000078900.10"; transcript_id "E...
# 5  gene_id "ENSG00000078900.10"; transcript_id "E...
# 6  gene_id "ENSG00000078900.10"; transcript_id "E...
# 7  gene_id "ENSG00000078900.10"; transcript_id "E...
# 8  gene_id "ENSG00000078900.10"; transcript_id "E...
# 9  gene_id "ENSG00000078900.10"; transcript_id "E...

# %%
def organize_column(l):
    if not pd.isnull(l): 
        l = l.replace('"', '')
        if l.split(";")[-1] in ['',' h']:
            l_d = dict(item.split() for item in l.split(";")[:-1])
        else:
            l_d = dict(item.split() for item in l.split(";"))
    else:
        l_d = np.nan

    return l_d

data['col'] = data[6].apply(lambda row : organize_column(row) )
df_pol_ps = data['col'].apply(pd.Series)
df_final = pd.concat([data, df_pol_ps], axis = 1)

del df_final[6] # remove column with geneid
del df_final['col']
del df_final[5] # remove column with + sign
df_final = df_final.drop(df_final.index[len(df_final)-1])
df_final.rename(columns={0:'PatientId', 1:'Chromosome', 2:'ExonStart', 3:'ExonEnd', 
                               4:'WPS'},inplace=True)
df_final = df_final.iloc[:, :-1]

# %%
df_final.head(10)
# Out:
#     PatientId Chromosome  ExonStart  ExonEnd  \
# 0  LIB-ZIIEJE       chr1    3598930  3598995
# 1  LIB-ZIIEJE       chr1    3599624  3599745
# 2  LIB-ZIIEJE       chr1    3624113  3624356
# 3  LIB-ZIIEJE       chr1    3624140  3624356
# 4  LIB-ZIIEJE       chr1    3638585  3638772
# 5  LIB-ZIIEJE       chr1    3639918  3640034
# 6  LIB-ZIIEJE       chr1    3643679  3643789
# 7  LIB-ZIIEJE       chr1    3644192  3644335
# 8  LIB-ZIIEJE       chr1    3644693  3644782
# 9  LIB-ZIIEJE       chr1    3645891  3646013
#
#                                                  WPS    ccdsid  \
# 0  -0.735294,-0.735294,-0.735294,-0.735294,-0.735...  CCDS49.1
# 1  -0.780822,-0.780822,-0.780822,-0.780822,-0.726...  CCDS49.1
# 2  -0.988372,-0.977011,-0.988372,-0.977011,-1.011...  CCDS49.1
# 3  -1.360465,-1.364706,-1.364706,-1.376471,-1.348...  CCDS49.1
# 4  -1.100000,-1.083333,-1.024000,-1.015873,-0.968...  CCDS49.1
# 5  -0.550000,-0.524752,-0.490000,-0.470000,-0.550...  CCDS49.1
# 6  -0.823529,-0.768116,-0.753623,-0.753623,-0.775...  CCDS49.1
# 7  -0.974359,-1.000000,-1.000000,-0.974359,-0.975...  CCDS49.1
# 8  -1.628571,-1.540541,-1.540541,-1.447368,-1.447...  CCDS49.1
# 9  -0.978261,-1.065217,-1.000000,-1.021277,-0.938...  CCDS49.1
#
#              exon_id exon_number             gene_id gene_name  ...  \
# 0  ENSE00000868857.1           2  ENSG00000078900.10      TP73  ...
# 1  ENSE00000358575.1           3  ENSG00000078900.10      TP73  ...
# 2  ENSE00003496607.1           4  ENSG00000078900.10      TP73  ...
# 3  ENSE00003496607.1           4  ENSG00000078900.10      TP73  ...
# 4  ENSE00003670865.1           5  ENSG00000078900.10      TP73  ...
# 5  ENSE00003526787.1           6  ENSG00000078900.10      TP73  ...
# 6  ENSE00003646577.1           7  ENSG00000078900.10      TP73  ...
# 7  ENSE00003503102.1           8  ENSG00000078900.10      TP73  ...
# 8  ENSE00003651642.1           9  ENSG00000078900.10      TP73  ...
# 9  ENSE00003693819.1          10  ENSG00000078900.10      TP73  ...
#
#         gene_type           havana_gene     havana_transcript level  \
# 0  protein_coding  OTTHUMG00000000610.5  OTTHUMT00000001468.4     2
# 1  protein_coding  OTTHUMG00000000610.5  OTTHUMT00000001468.4     2
# 2  protein_coding  OTTHUMG00000000610.5  OTTHUMT00000001468.4     2
# 3  protein_coding  OTTHUMG00000000610.5  OTTHUMT00000001468.4     2
# 4  protein_coding  OTTHUMG00000000610.5  OTTHUMT00000001468.4     2
# 5  protein_coding  OTTHUMG00000000610.5  OTTHUMT00000001468.4     2
# 6  protein_coding  OTTHUMG00000000610.5  OTTHUMT00000001468.4     2
# 7  protein_coding  OTTHUMG00000000610.5  OTTHUMT00000001468.4     2
# 8  protein_coding  OTTHUMG00000000610.5  OTTHUMT00000001468.4     2
# 9  protein_coding  OTTHUMG00000000610.5  OTTHUMT00000001468.4     2
#
#           protein_id   tag      transcript_id transcript_name  \
# 0  ENSP00000367545.4  CCDS  ENST00000378295.4        TP73-001
# 1  ENSP00000367545.4  CCDS  ENST00000378295.4        TP73-001
# 2  ENSP00000367545.4  CCDS  ENST00000378295.4        TP73-001
# 3  ENSP00000367545.4  CCDS  ENST00000378295.4        TP73-001
# 4  ENSP00000367545.4  CCDS  ENST00000378295.4        TP73-001
# 5  ENSP00000367545.4  CCDS  ENST00000378295.4        TP73-001
# 6  ENSP00000367545.4  CCDS  ENST00000378295.4        TP73-001
# 7  ENSP00000367545.4  CCDS  ENST00000378295.4        TP73-001
# 8  ENSP00000367545.4  CCDS  ENST00000378295.4        TP73-001
# 9  ENSP00000367545.4  CCDS  ENST00000378295.4        TP73-001
#
#   transcript_status transcript_type
# 0             KNOWN  protein_coding
# 1             KNOWN  protein_coding
# 2             KNOWN  protein_coding
# 3             KNOWN  protein_coding
# 4             KNOWN  protein_coding
# 5             KNOWN  protein_coding
# 6             KNOWN  protein_coding
# 7             KNOWN  protein_coding
# 8             KNOWN  protein_coding
# 9             KNOWN  protein_coding
#
# [10 rows x 21 columns]

# %%
df_final['PatientId'].unique()
# Out:
# array(['LIB-ZIIEJE'], dtype=object)

# %%
def len_wps(x):
    return len(x.split(','))

# %%
data['WPS Length']= df_final['WPS'].apply(lambda row : len_wps(row) )

# %%
def frag_profile(x):
    p = x.replace("\'", "").split(',')
    results = list(map(float, p))
    return results

# %%
fragmentprofile = df_final['WPS'].apply(lambda row : frag_profile(row))
for i in range(0,1):
    plt.plot(df_final['WPS'][i])
    plt.show

# %%
chr1 = df_final[df_final['Chromosome']=='chr1']['WPS'].values

# %%
z = np.array([])
for i in range(0,len(chr1)):
    z = np.concatenate((z,frag_profile(chr1[i])),axis=0)

# %%
plt.plot(z,'-k',linewidth=0.5)
plt.title('Chromosome 1')
plt.xlabel('Chromosome Position')
plt.ylabel('WPS')
plt.ylim((-15,5))
plt.show()

# %%
example_patientid = df_final['PatientId'].astype('string').unique()
example_ind = labels[labels['PatientId'].str.match(example_patientid[0])].index
example_purity = labels['estimated.purity'][example_ind.array[0]]
example_ctdna = labels['ctdna.score'][example_ind.array[0]]

# %%
print('For example patient ID %s -- the tissue purity is %s and circulating tumor DNA score is %s\n' % (example_patientid[0],example_purity,example_ctdna))
# Out:
# For example patient ID LIB-ZIIEJE -- the tissue purity is 0.87 and circulating tumor DNA score is 0.8065899648999999

# %%
a = df_final.groupby('Chromosome')['WPS'].apply(','.join).reset_index()

# %%
def chr_profile(x):
    p = x.split(',')
    results = list(map(float, p))
    return results

# %%
chrprofile = a['WPS'].apply(lambda row : frag_profile(row))

# %%
plt.plot(chrprofile[0],'-k',linewidth=0.5)
plt.xlabel('Chromosome Position')
plt.ylabel('WPS')
plt.ylim((-15,5))
plt.show()

# %%
##########################
# Testing out some metrics
##########################

# %%
test = chrprofile[0]

# %%
autocorr_test = np.correlate(test, test, mode='full')[len(test)-1:]

# %%
from scipy.signal import find_peaks
peaks_autocorr, _ = find_peaks(autocorr_test, height=0)

# %%
print('Second peak at index %s with max value of %s' % (peaks_autocorr[0],autocorr_test[peaks_autocorr[0]]))
# Out:
# Second peak at index 98 with max value of 563875.7072891564

# %%
plt.plot(autocorr_test);
plt.plot
plt.xlim([-10,1000]);

# %%
from scipy import signal
plt.plot(test,'0.75',linewidth=2);
plt.ylim(-15,5)
plt.plot(signal.savgol_filter(test,101,2),'-k',linewidth=0.25)

# %%
plt.plot(signal.savgol_filter(test,101,2),'-k',linewidth=0.25)

# %%
def modified_z_score(intensity):
    median_int = np.median(intensity)
    mad_int = np.median([np.abs(intensity - median_int)])
    modified_z_scores = 0.6745 * (intensity - median_int) / mad_int
    return modified_z_scores

# %%
def fixer(y,m):
    threshold = 7 # binarization threshold
    spikes = abs(np.array(modified_z_score(np.diff(y)))) > threshold
    y_out = y.copy() # So we don’t overwrite y
    for i in np.arange(len(spikes)):
        if spikes[i] != 0: # If we have an spike in position i
            w = np.arange(i-m,i+1+m) # we select 2 m + 1 points around our spike
            w2 = w[spikes[w] == 0] # From such interval, we choose the ones which are not spikes
            y_w2 = list(y[i] for i in w2)
            y_out[i] = np.mean(y_w2) # and we average their values
    return y_out

# %%
plt.plot(test,'0.75',linewidth=2);
plt.ylim(-15,5)
plt.plot(fixer(test,m=1),'-k',linewidth=0.5)
# Out:
# /Users/anamaria1/opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/anamaria1/opt/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
from scipy import signal
import pywt

# %%
j = 0
test = chrprofile[j]
scales = range(1,128)
waveletname = 'morl'
coeff, freq = pywt.cwt(test, scales, waveletname, 1)
coeff_ = coeff[:,:127]
plt.imshow(coeff_)
plt.title('Chromosome %s'%(j+1))
plt.axis('off');

# %%
import math 
fig, axs = plt.subplots(5,5)
#fig.suptitle('Individual patient sample')
scales = range(1,128)
waveletname = 'morl'
for j in range(0,22):
    j_row = math.floor(j/5)
    j_col = j%5
    #print(j,j_row,j_col)
    coeff, freq = pywt.cwt(chrprofile[j], scales, waveletname, 1)
    coeff_ = coeff[:,:127]
    axs[j_row,j_col].imshow(coeff_)
    axs[j_row,j_col].set_title('Chr %s'%(j+1))
    axs[j_row,j_col].axis('off');
    
fig.tight_layout()
#plt.savefig('SamplePatient_CWT_PerChromosome.eps', bbox_inches='tight')
plt.show()

# %%
####################################################################################
####################################################################################
####################################################################################
